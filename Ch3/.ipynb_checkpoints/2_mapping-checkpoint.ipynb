# %% [markdown]
# # 맛집 위치를 지도에 표시하기

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('03. best_sandwitches_list_chicago2.csv', index_col ='Rank')
df
# Out:
#                                                 Name  \
# Rank
# 1                                                BLT
# 2                                      Fried Bologna
# 3                                  Woodland Mushroom
# 4                                         Roast Beef
# 5                                               PB&L
# 6                        Belgian Chicken Curry Salad
# 7                                       Lobster Roll
# 8                                Smoked Salmon Salad
# 9                                    Atomica Cemitas
# 10    Grilled Laughing Bird Shrimp and Fried Po’ Boy
# 11                           Ham and Raclette Panino
# 12                                     Breaded Steak
# 13                                       The Hawkeye
# 14                                       Chicken Dip
# 15                              Wild Boar Sloppy Joe
# 16                                      Meatball Sub
# 17                                       Corned Beef
# ...

# %%
gmaps_key = 'AIzaSyDNK_5FJCc6n3PI_A5LoTxt4xKA2Fd935M'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
geo = gmaps.geocode('Delaware', language = 'en')
geo[0].get('geometry')
# Out:
# {'bounds': {'northeast': {'lat': 39.8394839, 'lng': -74.98416499999999},
#   'southwest': {'lat': 38.451018, 'lng': -75.78914790000002}},
#  'location': {'lat': 38.9108325, 'lng': -75.52766989999999},
#  'location_type': 'APPROXIMATE',
#  'viewport': {'northeast': {'lat': 39.8394839, 'lng': -74.98416499999999},
#   'southwest': {'lat': 38.451018, 'lng': -75.78914790000002}}}

# %%
lat = []
lng = []

for address in tqdm(df['address']):
    if 'Multiple' not in address:
        target_name = address + ', Chicago'
        gmaps_geocode = gmaps.geocode(target_name, language='en')
        
        location_output = gmaps_geocode[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.80it/s]

# %%
lat, lng
# Out:
# ([41.8956049,
#   41.8846582,
#   41.8905226,
#   42.0589141,
#   41.8866036,
#   41.9002461,
#   41.8590541,
#   41.9102031,
#   41.9097558,
#   41.8345302,
#   41.9276207,
#   nan,
#   41.9384419,
#   41.9451044,
#   41.9301107,
#   41.89129000000001,
#   41.8678529,
#   41.8852691,
#   41.9080539,
#   41.91369539999999,
#   41.9537106,
#   nan,
#   41.9794496,
#   41.9541563,
#   nan,
#   42.1567073,
#   nan,
#   41.9652987,
#   41.90272179999999,
#   41.8893683,
#   nan,
#   41.9105258,
#   41.8896188,
#   41.91504990000001,
#   41.9218521,
#   41.9797099,
#   41.9617122,
#   41.89296119999999,
#   nan,
#   41.9047551,
#   41.7913185,
#   41.7068231,
#   41.9152875,
#   41.8863622,
#   41.8758102,
#   41.8960738,
#   41.89897850000001,
#   41.9105832,
#   41.8831061,
#   41.9431632],
#  [-87.67996149999999,
#   -87.6476668,
#   -87.6307834,
#   -87.9940852,
#   -87.64853649999999,
#   -87.62516339999999,
#   -87.6252007,
#   -87.68287529999999,
#   -87.7176727,
#   -87.6456492,
# ...

# %% [markdown]
# - Pandas의 df['열이름'].mean() 메소드를 사용하기 위해. 자동적으로 nan값을 제외하고 return한다

# %%
df['lat'] = lat
df['lng'] = lng
df.head(15)
# Out:
#                                                 Name  \
# Rank
# 1                                                BLT
# 2                                      Fried Bologna
# 3                                  Woodland Mushroom
# 4                                         Roast Beef
# 5                                               PB&L
# 6                        Belgian Chicken Curry Salad
# 7                                       Lobster Roll
# 8                                Smoked Salmon Salad
# 9                                    Atomica Cemitas
# 10    Grilled Laughing Bird Shrimp and Fried Po’ Boy
# 11                           Ham and Raclette Panino
# 12                                     Breaded Steak
# 13                                       The Hawkeye
# 14                                       Chicken Dip
# 15                              Wild Boar Sloppy Joe
#
#                                  Menu  price                address  \
# Rank
# ...

# %%
''' 50개 위치의 평균값 두기 '''
mapping = folium.Map([df['lat'].mean(), df['lng'].mean()], zoom_start = 11)

folium.Marker([df['lat'].mean(), df['lng'].mean()], popup = 'center').add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map( [df['lat'].mean(), df['lng'].mean()] , zoom_start = 11)

for place in df['address']:
    if 'Multiple' not in place:
        folium.Marker( location = [ df['lat'][place], df['lng'][place] ] ,    
                      # 인덱싱에 문제가 있는 듯
                     popup = df['Name'][place] ).add_to(mapping)
mapping
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ' 2109 W Chicago Ave'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-0c76b9d2003f> in <module>
#       3 for place in df['address']:
#       4     if 'Multiple' not in place:
# ...
