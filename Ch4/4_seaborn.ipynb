# %% [markdown]
# # 셀프 주유소는 정말 저렴한지 boxplot으로 확인

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.font_manager
matplotlib.font_manager._rebuild()
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Malgun")])
# Out:
# ['Malgun Gothic', 'Malgun Gothic', 'Malgun Gothic']

# %%
# 폰트 설정
# mpl.rc('font', family='Malgun Gothic')
""" 왜 이게 되지?  """

plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
# 폰트 사이즈 조절
# plt.rcParams['font.size'] = 23

# figsize 를 전역으로 설정
# plt.rcParams['figure.figsize'] = (13, 8)

# %%
import pandas as pd
stations = pd.read_csv('04. stations.csv',sep=',',encoding='utf-8')
del stations['Unnamed: 0']
stations.head(15)
# Out:
#                       이름                         주소      가격 셀프      상표    구
# 0          지에스칼텍스㈜ 신월주유소     서울 강동구 양재대로 1323 (성내동)  1415.0  N   GS칼텍스  강동구
# 1         지에스칼텍스㈜ 동서울주유소     서울 강동구 천호대로 1456 (상일동)  1415.0  Y   GS칼텍스  강동구
# 2                 구천면주유소      서울 강동구 구천면로 357 (암사동)  1424.0  N  현대오일뱅크  강동구
# 3                방아다리주유소       서울 강동구 동남로 811 (명일동)  1435.0  Y   SK에너지  강동구
# 4        대성석유(주)직영 길동주유소           서울 강동구 천호대로 1168  1448.0  N   GS칼텍스  강동구
# 5        (주)퍼스트오일 코알라주유소  서울특별시 강동구  올림픽로 556 (성내동)  1448.0  Y   S-OIL  강동구
# 6      현대오일뱅크㈜직영 명일셀프주유소       서울 강동구 고덕로 168 (명일동)  1448.0  Y  현대오일뱅크  강동구
# 7               sk해뜨는주유소      서울 강동구  상일로 132 (강일동)  1455.0  Y   SK에너지  강동구
# 8       주)지유에너지직영 오렌지주유소       서울 강동구 성안로 102 (성내동)  1456.0  N   SK에너지  강동구
# 9      현대오일뱅크㈜직영 고속셀프주유소           서울 강동구 천호대로 1246  1457.0  Y  현대오일뱅크  강동구
# 10     현대오일뱅크㈜직영 암사셀프주유소      서울 강동구 올림픽로 749 (암사동)  1457.0  Y  현대오일뱅크  강동구
# 11               천호현대주유소        서울 강동구 천중로 67 (천호동)  1465.0  N  현대오일뱅크  강동구
# 12        (주)삼표에너지 고덕주유소        서울 강동구 고덕로 39 (암사동)  1478.0  N   GS칼텍스  강동구
# 13  (주)소모에너지엔테크놀러지 성내주유소      서울 강동구 올림픽로 578 (성내동)  1478.0  Y   GS칼텍스  강동구
# 14                 광성주유소      서울 강동구 올림픽로 673 (천호동)  1498.0  N   S-OIL  강동구

# %%
# 요거는 Pandas 데이터 시각화
stations.boxplot(column='가격',by='셀프', figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프'>

# %%
sns.set(style = 'ticks', color_codes = True)

plt.figure(figsize=(12,8))
sns.boxplot(x='상표',y='가격',hue='셀프', data = stations, palette='Set3')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표',y='가격', data = stations, palette='Set3')
sns.swarmplot(x='상표', y='가격', data= stations, color ='.6')
plt.show()
