# %%
''' 계층적 인덱스(Multi Index) - 정렬함수
# 고객 정보를 관리할 때, 고객의 주소를 index로 해서 데이터를 관리한다고 가정하자.
# 가장 큰 계층인 시(군) 부터 작은 계층인 번지까지 하나씩 내려올 것이다. ex> 서울특별시 강남구 삼성로 212
# 이렇게 계층적인 정보를 index로 사용하고 싶을 때, 이를 계층적 인덱스라고 한다.

아래 예처럼 인덱스를 2차원 리스트(2차원 Array)로 주면, 층이 2개([x,x,x,...],[0,1,2,3...])인 Index를 가진다
'''
import pandas as pd
import numpy as np
srs = pd.DataFrame(np.random.rand(10,2),
                columns = ['X','Y'],
               index = 
               [
                   ["a","a","a","b","b","b","c","c","d","d"],
                   [1,2,3,1,2,3,1,2,2,3]
               ])
print(srs.index)  
''' index는 메소드가 아니라, 특징이다!
실제로 Index를 확인해보면 Multiindex라고 나온다 '''

print(srs)
''' 인덱싱은 가장 바깥층부터 인덱싱하는게 원칙이다.
'''
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )
#             X         Y
# a 1  0.913607  0.475973
#   2  0.181526  0.858631
#   3  0.187943  0.497748
# b 1  0.440488  0.584169
#   2  0.674895  0.533686
#   3  0.888444  0.050110
# c 1  0.773866  0.415152
#   2  0.850854  0.988645
# d 2  0.151670  0.162858
#   3  0.489737  0.619686
